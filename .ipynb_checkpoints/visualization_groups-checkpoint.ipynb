# %%
from matplotlib import pyplot as plt
import matplotlib.ticker as ticker
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import metrics
import warnings
import json
from pathlib import Path
from collections import defaultdict
from scorer import ScorerInfo
warnings.filterwarnings("ignore", "is_categorical_dtype")
warnings.filterwarnings("ignore", "use_inf_as_na")
warnings.filterwarnings("ignore", "is_sparse")
from math import pi

path_to_base = Path('/home/dpenzar/nikgr')

from matplotlib import rcParams
# rcParams['font.serif'] = "Roboto"
# rcParams['font.family'] = "serif"

# %%
calcs = {'auROC': ScorerInfo("prroc_rocauc", "rocauc").make(),
         'auPRC': ScorerInfo("prroc_prauc", "prauc", params={"type": "integral"}).make()}

# %%
def get_model_name(model_type):
    match model_type:
        case 1:
            return 'LegNet'
        case 2:
            return 'LegNet&PWMs'
        case 3:
            return 'PWMNet'
        case 4:
            return 'PWM'
        case 5:
            return 'ArChIPelago'
def get_model_color(model_type):
    match model_type:
        case 1:
            return 'crimson'
        case 2:
            return 'green'
        case 3:
            return 'orange'
        case 4:
            return 'mediumorchid'
        case 5:
            return 'darkblue'
        case _:
            if isinstance(model_type, int):
                raise ValueError('No such key')
    return get_model_color(get_model_name(model_type))
def get_mode_marker(mode):
    match mode:
        case 'Training':
            return '^'
        case 'Validation':
            return 'X'
        case 'Testing':
            return 'o'
model_palette = {get_model_name(x):get_model_color(x) for x in range(1, 6)}
marker_collection = {x:get_mode_marker(x) for x in ('Training', 'Validation', 'Testing')}
experiments = ('CHS', 'GHTS')
size=150
alpha=0.6

# %%
preds = ('forw_pred', 'avg_pred', 'rev_pred')
preds_names = {'forw_pred': 'forward', 'rev_pred': 'reverse', 'avg_pred': 'averaged'}

def transform_metrics_df(df):
    left_df = df[['val_loss', 'val_auroc', 'epoch', 'step']].dropna()
    right_df = df[['epoch', 'step', 'train_loss']].dropna()
    return pd.merge(left_df, right_df, on=['epoch', 'step'])

def transform_preds_df(df):
    df['avg_pred'] = (df['forw_pred'] + df['rev_pred']) / 2
    return df

# %%
def get_proper_validation_metric(df, name):
    # return df.loc[df['val_loss'].idxmin()][name]
    return df.loc[df[name].idxmax()][name]

# %%
def group_paths(to_group, path_depth, convert_key=int):
    grouped = defaultdict(dict)
    for entry in to_group:
        name_full = entry.parents[path_depth].name
        name = name_full[:name_full.rindex('-')]
        key = convert_key(name_full[name_full.rindex('-')+1:])
        grouped[name][key] = entry
    return grouped

def read_groups(paths, sep, transform=None):
    read = defaultdict(dict)
    for name, value in paths.items():
        for key, path in value.items():
            df = pd.read_csv(path, sep=sep)
            if transform:
                df = transform(df)
            read[name][key] = df
    return read

# %%
negatives_to = 'random'
path_to_group = path_to_base / 'mex_models_prod/finalize_run'
group_metrics_paths = path_to_group.rglob('*/model/lightning_logs/version_0/metrics.csv')
group_preds_paths = path_to_group.rglob(f'*/model/predictions_new_format_cross_{negatives_to}.tsv')

grouped_metrics_paths = group_paths(group_metrics_paths, 3)
grouped_preds_paths = group_paths(group_preds_paths, 1)

grouped_metrics = read_groups(grouped_metrics_paths, ',', transform_metrics_df)
grouped_preds = read_groups(grouped_preds_paths, '\t', transform_preds_df)
print(path_to_group)
print(grouped_metrics_paths.keys())
print(grouped_preds_paths.keys())
# Out:
# /home/dpenzar/nikgr/mex_models_prod/finalize_run
# dict_keys(['ZSCAN2-GHTS-CHS', 'ZNF836-GHTS-CHS', 'CREB3L3-CHS-GHTS', 'ZNF770-CHS-GHTS', 'TET3-CHS-GHTS', 'ZNF43-GHTS-CHS', 'MYPOP-CHS-GHTS', 'ZNF384-CHS-GHTS', 'GABPA-CHS-GHTS', 'ZNF335-GHTS-CHS', 'NR1H4-GHTS-CHS', 'GABPA-GHTS-CHS', 'ZFP3-GHTS-CHS', 'ZNF131-CHS-GHTS', 'ZNF107-GHTS-CHS', 'ZNF510-GHTS-CHS', 'ZNF773-GHTS-CHS', 'ZNF772-CHS-GHTS', 'ZNF234-CHS-GHTS', 'ZNF226-CHS-GHTS'])
# dict_keys(['ZSCAN2-GHTS-CHS', 'ZNF836-GHTS-CHS', 'CREB3L3-CHS-GHTS', 'ZNF770-CHS-GHTS', 'TET3-CHS-GHTS', 'ZNF43-GHTS-CHS', 'MYPOP-CHS-GHTS', 'ZNF384-CHS-GHTS', 'GABPA-CHS-GHTS', 'ZNF335-GHTS-CHS', 'NR1H4-GHTS-CHS', 'GABPA-GHTS-CHS', 'ZFP3-GHTS-CHS', 'ZNF131-CHS-GHTS', 'ZNF107-GHTS-CHS', 'ZNF510-GHTS-CHS', 'ZNF773-GHTS-CHS', 'ZNF772-CHS-GHTS', 'ZNF234-CHS-GHTS', 'ZNF226-CHS-GHTS'])

# %%
figsize = [x / 1 for x in (20, 15)]

fig_loss, axs_loss = plt.subplots(5, 4, figsize=figsize, layout='constrained',
                                  sharex=True, sharey=False)
fig_loss.suptitle('Loss vs Epoch')

for (tf_exp, value), ax in zip(grouped_metrics.items(), axs_loss.flat):
    tf, exp1, exp2 = tf_exp.split('-')
    # ax = plt.axes()
    ax.set_title(f'{tf} {exp1}')
    max_loss = 0
    for model_type, metrics_df in value.items():
        model_name = get_model_name(model_type)
        model_color = get_model_color(model_type)
        ax.plot(metrics_df['epoch'], metrics_df['val_loss'], label=f'{model_name} Validation Loss', color=model_color, linestyle='dotted')
        ax.plot(metrics_df['epoch'], metrics_df['train_loss'], label=f'{model_name} Training Loss', color=model_color, linestyle='solid')
        max_loss = max(metrics_df['val_loss'].max(), metrics_df['train_loss'].max(), max_loss)
        
    ax.set_ylim(0, max_loss)
    
    ax.set_ylabel('Loss')
    ax.set_xlabel('Epoch #')
    # ax.legend(loc='upper right')
    # plt.show()
    
handles, labels = ax.get_legend_handles_labels()
fig_loss.legend(handles, labels, loc='lower right', bbox_to_anchor=(1,1))

# %%
figsize = [x / 1 for x in (20, 15)]

fig_val, axs_val = plt.subplots(5, 4, figsize=figsize, layout='constrained',
                                  sharex=True, sharey=True)
fig_val.suptitle('Validation auROC vs epoch')

for (tf_exp, value), ax in zip(grouped_metrics.items(), axs_val.flat):
    tf, exp1, exp2 = tf_exp.split('-')
    # ax = plt.axes()
    ax.set_title(f'{tf} {exp1}')
    min_auroc = 1
    for model_type, metrics_df in value.items():
        model_name = get_model_name(model_type)
        model_color = get_model_color(model_type)
        ax.plot(metrics_df['epoch'], metrics_df['val_auroc'], label=f'{model_name}', color=model_color, linestyle='dotted')
        min_auroc = min(metrics_df['val_auroc'].min(), min_auroc)

    ax.set_ylim(min_auroc, 1)
    ax.set_ylabel('Validation AUROC')
    ax.set_xlabel('Epoch #')

handles, labels = ax.get_legend_handles_labels()
fig_val.legend(handles, labels, loc='lower right', bbox_to_anchor=(1,1))

# %%
def plot_scatterplot_metrics(df, metric_name, ylim=0.0, figsize=None, title=None):
    sns.set_style('whitegrid')
    if figsize is None:
        figsize = [x / 2 for x in (20, 15)]
    if title is None:
        title = f'{metric_name} values'
    fig, axs = plt.subplots(1, 2, figsize=figsize, layout='constrained',
                                  sharex=False, sharey=True)
    fig.suptitle(title)
    for exp1, exp2, ax in zip(experiments, reversed(experiments), axs.flat):
        plot_values_exp = df.loc[df['Experiment'] == exp1]

        g = sns.scatterplot(data=plot_values_exp, 
                            x='TF', 
                            y=metric_name, 
                            hue='Model type', 
                            s=size, 
                            alpha=alpha, 
                            palette=model_palette, 
                            markers=marker_collection, 
                            ax=ax)
        sns.move_legend(g, "upper left", bbox_to_anchor=(1, 1))
        g.set(ylim=(ylim, 1))
        ax.axhline(y=0.5, ls=':', c='grey')
        g.set(title=f'{exp1}/{exp2}')
        g.yaxis.set_major_locator(ticker.MultipleLocator(0.1))
        ax.get_legend().set_visible(False)
    handles, labels = ax.get_legend_handles_labels()
    fig.legend(handles, labels, loc='lower right', bbox_to_anchor=(1,1))

# %%
plot_columns = ['auROC', 'TF', 'Model type', 'Experiment']
plot_values = pd.DataFrame(columns=plot_columns)
for tf_exp, value in grouped_metrics.items():
    tf, exp1, exp2 = tf_exp.split('-')
    for model_type, preds_df in value.items():
        plot_values.loc[len(plot_values)] = [get_proper_validation_metric(preds_df, 'val_auroc'), tf, get_model_name(model_type), exp1]

plot_scatterplot_metrics(plot_values, 'auROC', title='max auROC values on validation step across all epocs')

# %%
tfs_by_exp = {exp:plot_values[plot_values['Experiment'] == exp]['TF'].unique() for exp in experiments}
tfs_sorted = {
    'CHS': ['CREB3L3', 'GABPA', 'MYPOP', 'TET3', 'ZNF131', 'ZNF226', 'ZNF234', 'ZNF384', 'ZNF770', 'ZNF772'],
    'GHTS': ['GABPA', 'NR1H4', 'ZFP3', 'ZNF107', 'ZNF335', 'ZNF43', 'ZNF510', 'ZNF773', 'ZNF836', 'ZSCAN2']
}

# %%
plot_columns = ['auROC', 'auPRC', 'TF', 'Model type', 'Experiment', 'Experiment to']
def get_Archipelago_data():
    path_to_Archipelago_data = path_to_base / 'MEX/Archipelago_data'
    arch_dfs_paths = path_to_Archipelago_data.rglob(f'*Random{negatives_to.capitalize()}*_cut.csv')
    for path in arch_dfs_paths:
        splitted_name = path.stem.split('_')
        exp1 = splitted_name[2]
        exp2 = splitted_name[5]
        negative = splitted_name[7]
        df = pd.read_csv(path, sep=';')
        yield (exp1, exp2, negative, df)
    
def add_Archipelago_data(tfs_by_exp):
    plt_vls = pd.DataFrame(columns=plot_columns)
    for exp1, exp2, negative, df in get_Archipelago_data(): 
        print(exp1, exp2, negative)
        subdf = df[df['TF_name'].isin(tfs_by_exp[exp1])]
        for idx, row in subdf.iterrows():
            plt_vls.loc[len(plt_vls)] = [row[f'roc_auc_test_{exp2}_PWM'], row[f'pr_auc_test_{exp2}_PWM'], row['TF_name'], get_model_name(4), exp1, exp2]
            plt_vls.loc[len(plt_vls)] = [row[f'roc_auc_test_{exp2}'], row[f'pr_auc_test_{exp2}'], row['TF_name'], get_model_name(5), exp1, exp2]
    
    return plt_vls
    

add_Archipelago_data(tfs_by_exp)
# Out:
# GHTS CHS RandomRandom
# CHS GHTS RandomRandom
#        auROC     auPRC       TF   Model type Experiment Experiment to
# 0   0.497717  0.040693   ZSCAN2          PWM       GHTS           CHS
# 1   0.550077  0.045974   ZSCAN2  ArChIPelago       GHTS           CHS
# 2   0.633986  0.066014   ZNF107          PWM       GHTS           CHS
# 3   0.760076  0.184437   ZNF107  ArChIPelago       GHTS           CHS
# 4   0.735896  0.073090   ZNF510          PWM       GHTS           CHS
# 5   0.754189  0.107344   ZNF510  ArChIPelago       GHTS           CHS
# 6   0.721717  0.050018    GABPA          PWM       GHTS           CHS
# 7   0.780210  0.082124    GABPA  ArChIPelago       GHTS           CHS
# 8   0.791068  0.613854     ZFP3          PWM       GHTS           CHS
# 9   0.912287  0.672188     ZFP3  ArChIPelago       GHTS           CHS
# 10  0.741182  0.031203    ZNF43          PWM       GHTS           CHS
# 11  0.836752  0.140483    ZNF43  ArChIPelago       GHTS           CHS
# ...

# %%
def get_dataset_statistics():
    replace_names = {
        'positives.bed': 'positives',
        'foreigns.bed': 'foreigns',
        'random_addshift.bed': 'random',
        'shades_addshift.bed': 'shades'
    }
    path_to_ds_statistics = path_to_base / 'MEX/Archipelago_data'
    print(path_to_ds_statistics)
    ds_stat_paths = path_to_ds_statistics.rglob('dataset_statistics_*.txt')
    ds_stat = [pd.read_csv(x, sep=',', header=None) for x in ds_stat_paths]
    ds_stat = pd.concat(ds_stat)
    ds_stat[0] = ds_stat[0].str.strip()
    ds_stat[[0, 1]] = ds_stat[0].str.split(' ', n=1, expand=True)
    ds_stat[list(range(1, 5))] = ds_stat[1].str.rsplit('/', n=4, expand=True).drop(0, axis=1)
    ds_stat.columns = ['Count', 'Experiment', 'Split', 'TF', 'Seq type']
    ds_stat[['Count']] = ds_stat[['Count']].astype(int)
    return ds_stat.replace(replace_names).dropna()

get_dataset_statistics()
# Out:
# /home/dpenzar/nikgr/MEX/Archipelago_data
#       Count Experiment  Split       TF   Seq type
# 0     12258        CHS   Test    BATF2  positives
# 1       878        CHS   Test   CAMTA1  positives
# 2        68        CHS   Test   CAMTA2  positives
# 3      6323        CHS   Test   CGGBP1  positives
# 4       398        CHS   Test  CREB3L3  positives
# ..      ...        ...    ...      ...        ...
# 563  268400       GHTS  Train   ZNF845   foreigns
# 564  329100       GHTS  Train   ZNF850   foreigns
# 565  539731       GHTS  Train   ZNF865   foreigns
# 566  221700       GHTS  Train  ZSCAN25   foreigns
# 567   49100       GHTS  Train   ZSCAN2   foreigns
#
# [4544 rows x 5 columns]

# %%
def get_dataset_statistics_():
    replace_names = {
        'positives.bed': 'positives',
        'foreigns.bed': 'foreigns',
        'random_addshift.bed': 'random',
        'shades_addshift.bed': 'shades'
    }
    path_to_ds_statistics = path_to_base / 'MEX/Archipelago_data'
    print(path_to_ds_statistics)
    ds_stat_paths = path_to_ds_statistics.rglob('dataset_statistics_*.txt')
    ds_dfs = []
    for ds_path in ds_stat_paths:
        ds_df = pd.DataFrame(columns=['Experiment', 'Split', 'Seq type', 'TF', 'Count'])
        with open(ds_path, 'r') as ds_file:
            for line in ds_file.readlines():
                clear_line = line.lstrip()
                count, path = clear_line.split()
                path_split = list(reversed(path.split('/')))
                if len(path_split) < 4:
                    continue
                seq_type_bed, tf, split, exp, *_ = path_split
                ds_df.loc[len(ds_df)] = [exp, split, replace_names[seq_type_bed], tf, int(count)]
        ds_dfs.append(ds_df)
    return pd.concat(ds_dfs)
    
get_dataset_statistics_()
# Out:
# /home/dpenzar/nikgr/MEX/Archipelago_data
#     Experiment  Split   Seq type       TF   Count
# 0          CHS   Test  positives    BATF2   12258
# 1          CHS   Test  positives   CAMTA1     878
# 2          CHS   Test  positives   CAMTA2      68
# 3          CHS   Test  positives   CGGBP1    6323
# 4          CHS   Test  positives  CREB3L3     398
# ..         ...    ...        ...      ...     ...
# 563       GHTS  Train   foreigns   ZNF845  268400
# 564       GHTS  Train   foreigns   ZNF850  329100
# 565       GHTS  Train   foreigns   ZNF865  539731
# 566       GHTS  Train   foreigns  ZSCAN25  221700
# 567       GHTS  Train   foreigns   ZSCAN2   49100
#
# [4544 rows x 5 columns]

# %%
plot_values_orig = pd.DataFrame(columns=plot_columns)

for tf_exp, value in grouped_preds.items():
    tf, exp1, exp2 = tf_exp.split('-')
    for model_type, preds_df in value.items():
        for pred in ('avg_pred',):
            # auc = metrics.roc_auc_score(preds_df['class_'], preds_df[pred])
            auc = calcs['auROC'].score(preds_df[pred], preds_df['class_'])
            pr = calcs['auPRC'].score(preds_df[pred], preds_df['class_'])
            plot_values_orig.loc[len(plot_values_orig)] = [auc, pr, tf, get_model_name(model_type), exp1, exp2]

# %%
plot_values_orig = plot_values_orig.sort_values(by='auROC')
Archipelago_data = add_Archipelago_data(tfs_by_exp)
plot_values_all = pd.concat([plot_values_orig, Archipelago_data])
plot_values_all['auROC & auPRC avg.'] = plot_values_all[['auROC', 'auPRC']].mean(axis=1)
# Out:
# GHTS CHS RandomRandom
# CHS GHTS RandomRandom

# %%
def get_exp_name(exp):
    if exp == 'CHS':
        return 'ChIP-seq'
    if exp == 'GHTS':
        return 'Genomic HT-SELEX'

# %%
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 12}
from matplotlib import rc
rc('font', **font)

# %%
def extend_row(row):
    row = list(row)
    return row + [row[0]]

def plot_radarplot_metrics(df, metric_name, ylim=0.0, figsize=None, title=None, set_y_min_max=False, exclude_models=None):
    sns.set_style('whitegrid')
    # rcParams["axes.axisbelow"] = True
    if exclude_models is None:
        exclude_models = []
    if figsize is None:
        figsize = [x / 1.5 for x in (20, 10)]
    if title is None:
        title = f'{metric_name} values, random → {negatives_to} negatives'
    fig, axs = plt.subplots(1, 2, figsize=figsize, layout='constrained',
                                  sharex=False, sharey=False, subplot_kw=dict(projection="polar"))
    fig.suptitle(title, size=15)
    
    plot_vals = df.loc[~df['Model type'].isin(exclude_models)]
    for exp1, exp2, ax in zip(experiments, reversed(experiments), axs.flat):
        plot_vals_exp = plot_vals.loc[plot_vals['Experiment'] == exp1]
        pivoted = plot_vals_exp.pivot(index='Model type', columns='TF', values=metric_name)

        label_loc = np.linspace(start=0, stop=2 * np.pi, num=len(pivoted.columns)+1)#, endpoint=False)
        for idx, row in pivoted.iterrows():
            # if idx not in exclude_models:
            ax.plot(label_loc, extend_row(row), label=idx, color=model_palette[idx], linewidth=2)
            
        ax.set_title(f'{get_exp_name(exp1)} → {get_exp_name(exp2)}', size=15)
        lines, labels = ax.set_thetagrids(np.degrees(label_loc[:-1]), labels=pivoted.columns)
        for label, text in zip(labels, pivoted.columns):
            best_model = pivoted[text].idxmax()
            label.set(color=model_palette[best_model])
            label.set(zorder=100000)
            label.set_fontweight('semibold')
        # ax.set_axisbelow(True)
        if set_y_min_max:
            delta = 0.01
            min_y = max(0, np.nanmin(pivoted.to_numpy()) - delta)
            max_y = min(1, np.nanmax(pivoted.to_numpy()) + delta)
            ax.set_rlim(min_y, max_y)
            ax.set_rticks(np.arange(np.floor(min_y * 10) / 10, np.ceil(max_y * 10) / 10, 0.1))
        else:
            ax.set_ylim(ylim, 1)
            ax.set_rticks(np.arange(0, 1.1, 0.1))
    handles, labels = ax.get_legend_handles_labels()
    fig.legend(handles, labels, loc='lower right', bbox_to_anchor=(1,0.95), title='Model', title_fontsize=11)
    minmaxed = 'minmaxed' if set_y_min_max else ''
    excl = '+'.join(exclude_models)
    plt.savefig(f'output/radarplot_metrics_{metric_name}_{negatives_to}_{minmaxed}_{excl}.png'.replace(' ', '_'),bbox_inches='tight')

# %%
plot_radarplot_metrics(plot_values_all, 'auROC', set_y_min_max=True, exclude_models=['PWMNet', 'ArChIPelago'])
plot_radarplot_metrics(plot_values_all, 'auPRC', set_y_min_max=True, exclude_models=['PWMNet', 'ArChIPelago'])
plot_radarplot_metrics(plot_values_all, 'auPRC', set_y_min_max=True, exclude_models=['PWMNet', 'ArChIPelago'])

# %%
plot_radarplot_metrics(plot_values_all, 'auROC', exclude_models=['PWMNet'])
plot_radarplot_metrics(plot_values_all, 'auPRC', exclude_models=['PWMNet'])

# %%
get_dataset_statistics()
# Out:
# /home/dpenzar/nikgr/MEX/Archipelago_data
#       Count Experiment  Split       TF   Seq type
# 0     12258        CHS   Test    BATF2  positives
# 1       878        CHS   Test   CAMTA1  positives
# 2        68        CHS   Test   CAMTA2  positives
# 3      6323        CHS   Test   CGGBP1  positives
# 4       398        CHS   Test  CREB3L3  positives
# ..      ...        ...    ...      ...        ...
# 563  268400       GHTS  Train   ZNF845   foreigns
# 564  329100       GHTS  Train   ZNF850   foreigns
# 565  539731       GHTS  Train   ZNF865   foreigns
# 566  221700       GHTS  Train  ZSCAN25   foreigns
# 567   49100       GHTS  Train   ZSCAN2   foreigns
#
# [4544 rows x 5 columns]

# %%
testing_ds = get_dataset_statistics_()
testing_ds.loc[(testing_ds['Experiment'] == 'CHS') & (testing_ds['Seq type'] == 'positives') & ((testing_ds['Split'] == 'Test')) & testing_ds['TF'].isin(tfs_by_exp['CHS'])]
# Out:
# /home/dpenzar/nikgr/MEX/Archipelago_data
#     Experiment Split   Seq type       TF   Count
# 4          CHS  Test  positives  CREB3L3     398
# 16         CHS  Test  positives    GABPA    8076
# 28         CHS  Test  positives    MYPOP   13825
# 48         CHS  Test  positives     TET3    7283
# 69         CHS  Test  positives   ZNF131    6944
# 75         CHS  Test  positives   ZNF226     335
# 77         CHS  Test  positives   ZNF234     486
# 90         CHS  Test  positives   ZNF384  105319
# 127        CHS  Test  positives   ZNF770   36585
# 128        CHS  Test  positives   ZNF772     223
# 4          CHS  Test  positives  CREB3L3     398
# 16         CHS  Test  positives    GABPA    8076
# 28         CHS  Test  positives    MYPOP   13825
# 48         CHS  Test  positives     TET3    7283
# 69         CHS  Test  positives   ZNF131    6944
# 75         CHS  Test  positives   ZNF226     335
# 77         CHS  Test  positives   ZNF234     486
# ...

# %%
def normalize_list(values, log=False):
    if not log:
        max_value = max(values)
        return [x / max_value for x in values]
    if log:
        log_vals = np.log10(values)
        max_value = np.max(log_vals)
        return log_vals / max_value

# %%
def group_ds_counts(df, tfs_by_exp):
    # for seq_type, seq_type_grouped in plot_values_exp.groupby(['Seq type']):
    #         for split, grouped in seq_type_grouped.groupby(['Split']):
    #             print(seq_type[0], split[0], grouped)
    for (exp, seq_type, split), seq_type_grouped in df.sort_values(by='Count').groupby(['Experiment', 'Seq type', 'Split']):
        df_filtered = seq_type_grouped.loc[seq_type_grouped['TF'].isin(tfs_by_exp[exp])]
        yield exp, split, seq_type, df_filtered['TF'].to_list(), df_filtered['Count'].to_list()

def plot_radarplot_ds(df, negatives=None, ylim=0.0, figsize=None, title=None, set_y_min_max=False):
    seq_type_colors = {
        'positives': 'tab:blue',
        'foreigns': 'tab:orange',
        'random': 'tab:red',
        'shades': 'tab:green'
    }
    sns.set_style('whitegrid')
    # if exclude_models is None:
    #     exclude_models = []
    if figsize is None:
        figsize = [x / 1.5 for x in (20, 10)]
    if title is None:
        title = 'Dataset sizes (peaks count)'
    fig, axs = plt.subplots(1, 2, figsize=figsize, layout='constrained',
                                  sharex=False, sharey=False, subplot_kw=dict(projection="polar"))
    fig.suptitle(title, size=15) 
    plot_vals = df if negatives is None else df.loc[df['Seq type'].isin(['positives', negatives])]
    for exp1, exp2, ax in zip(experiments, reversed(experiments), axs.flat):
        plot_vals_exp = plot_vals.loc[plot_vals['Experiment'] == exp1]
        plot_vals_exp = plot_vals_exp.loc[plot_vals_exp['TF'].isin(tfs_by_exp[exp1])]
        pivoted = plot_vals_exp.pivot(index=['Seq type', 'Split'], columns='TF', values='Count')
        label_loc = np.linspace(start=0, stop=2 * np.pi, num=len(pivoted.columns)+1)
        
        for (seq_type, split), row in pivoted.iterrows():
            c = 'tab:blue' if seq_type == 'positives' else 'tab:red'
            l = '-' if split == 'Train' else ':'
            # if seq_type == 'positives':# or split == 'Train':
            #     continue
            ax.plot(label_loc, extend_row(row), label=f'{seq_type.capitalize()}, {split}', color=seq_type_colors[seq_type], linestyle=l)#, linestyle=':')
            # ax.fill(label_loc, extend_row(row), label=f'{seq_type}, {split}', alpha=0.4)
        ax.set_title(f'{get_exp_name(exp1)}', size=15)
        lines, labels = ax.set_thetagrids(np.degrees(label_loc[:-1]), labels=pivoted.columns)
        ax.set_rscale('symlog')
        # ax.set_rlim(0, 2*10**7)

    
    handles, labels = ax.get_legend_handles_labels()
    fig.legend(handles, labels, loc='lower right', bbox_to_anchor=(1,0.85),title='Negatives type, Split', title_fontsize=11)
    neg_used = 'negatives_all' if negatives is None else f'positives_{negatives}' 
    plt.savefig(f'output/radarplot_ds_{neg_used}.png',bbox_inches='tight')

plot_radarplot_ds(get_dataset_statistics_().drop_duplicates())
# Out:
# /home/dpenzar/nikgr/MEX/Archipelago_data
